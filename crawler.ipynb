# %%
from selenium import webdriver
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys
import time
import urllib.request
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

s = Service('./chromedriver')
driver = webdriver.Chrome(service=s) #
driver.get("https://www.google.co.kr/imghp?hl=ko&ogbl")
elem = driver.find_element(By.NAME,"q")
search = "아이유 소니 이어폰" ## 검색어 넣기
elem.send_keys(search) 
elem.send_keys(Keys.RETURN)
 
SCROLL_PAUSE_TIME = 1
 
last_height = driver.execute_script("return document.body.scrollHeight")
 
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
 
    time.sleep(SCROLL_PAUSE_TIME)
 
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        try:
            driver.find_element(By.CSS_SELECTOR,".mye4qd").click()
        except:
            break
    last_height = new_height
 
images = driver.find_elements(By.CSS_SELECTOR,".rg_i.Q4LuWd")
count = 1
for image in images:
    try: 
        image.click()
        time.sleep(4)
        imgUrl = driver.find_element(By.XPATH,'//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img').get_attribute("src")
        urllib.request.urlretrieve(imgUrl,"C:/Users/R/Desktop/test1/images/"+"iuearphone"+str(count) + ".jpg")
        print("파일:{} 다운완료 | 현재:{}개 파일 다운완료".format("iuearphone"+str(count),count))
        count = count + 1
        if count == 300:
            break
    except:
        print("저장에 실패했습니다")
        pass
 
driver.close()
# Out:
# 저장에 실패했습니다
# 저장에 실패했습니다
# 저장에 실패했습니다
# 파일:iuearphone1 다운완료 | 현재:1개 파일 다운완료
# 파일:iuearphone2 다운완료 | 현재:2개 파일 다운완료
# 파일:iuearphone3 다운완료 | 현재:3개 파일 다운완료
# 파일:iuearphone4 다운완료 | 현재:4개 파일 다운완료
# 파일:iuearphone5 다운완료 | 현재:5개 파일 다운완료
# 파일:iuearphone6 다운완료 | 현재:6개 파일 다운완료
# 파일:iuearphone7 다운완료 | 현재:7개 파일 다운완료
# 파일:iuearphone8 다운완료 | 현재:8개 파일 다운완료
# 파일:iuearphone9 다운완료 | 현재:9개 파일 다운완료
# 파일:iuearphone10 다운완료 | 현재:10개 파일 다운완료
# 파일:iuearphone11 다운완료 | 현재:11개 파일 다운완료
# 파일:iuearphone12 다운완료 | 현재:12개 파일 다운완료
# 파일:iuearphone13 다운완료 | 현재:13개 파일 다운완료
# 파일:iuearphone14 다운완료 | 현재:14개 파일 다운완료
# 파일:iuearphone15 다운완료 | 현재:15개 파일 다운완료
# 파일:iuearphone16 다운완료 | 현재:16개 파일 다운완료
# 파일:iuearphone17 다운완료 | 현재:17개 파일 다운완료
# 파일:iuearphone18 다운완료 | 현재:18개 파일 다운완료
# 파일:iuearphone19 다운완료 | 현재:19개 파일 다운완료
# 파일:iuearphone20 다운완료 | 현재:20개 파일 다운완료
# 파일:iuearphone21 다운완료 | 현재:21개 파일 다운완료
# 파일:iuearphone22 다운완료 | 현재:22개 파일 다운완료
# 파일:iuearphone23 다운완료 | 현재:23개 파일 다운완료
# 파일:iuearphone24 다운완료 | 현재:24개 파일 다운완료
# ...

# %%
## 파일이름 바꾸기
import os

path = "./helmet/"

# %%
count=1
for file in os.listdir(path):
    os.rename(path+file, path+"helmet"+str(count)+".jpg")
    count+=1
